# %%
#import zipfile as zf
#files = zf.ZipFile("shopee-product-matching.zip", 'r')
#files.extractall('Product_Matching_Resnet')
#files.close()

# %%
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
import tensorflow as tf
import keras as K
import pandas as pd
import os
from tensorflow.keras.applications.resnet import ResNet50
from keras.models import Sequential
from tensorflow.keras.applications.resnet import preprocess_input
from tensorflow.keras.preprocessing import image

#from tensorflow.keras.applications.efficientnet import preprocess_input,EfficientNetB3

# %%
train_data = pd.read_csv('Product_Matching_Resnet/train.csv')
train_data
# Out:
#              posting_id                                 image  \
# 0       train_129225211  0000a68812bc7e98c42888dfb1c07da0.jpg
# 1      train_3386243561  00039780dfc94d01db8676fe789ecd05.jpg
# 2      train_2288590299  000a190fdd715a2a36faed16e2c65df7.jpg
# 3      train_2406599165  00117e4fc239b1b641ff08340b429633.jpg
# 4      train_3369186413  00136d1cf4edede0203f32f05f660588.jpg
# ...                 ...                                   ...
# 34245  train_4028265689  fff1c07ceefc2c970a7964cfb81981c5.jpg
# 34246   train_769054909  fff401691371bdcb382a0d9075dfea6a.jpg
# 34247   train_614977732  fff421b78fa7284284724baf249f522e.jpg
# 34248  train_3630949769  fff51b87916dbfb6d0f8faa01bee67b8.jpg
# 34249  train_1792180725  ffffa0ab2ae542357671e96254fa7167.jpg
#
#             image_phash                                              title  \
# 0      94974f937d4c2433                          Paper Bag Victoria Secret
# ...

# %%
BATCH_SIZE=8
IMAGE_SIZE=[512,512]
SEED=42
VERBOSE=1
N_CLASSES=train_data['label_group'].nunique()
path='Product_Matching_Resnet/train_images'

# %%
def decode_image(image_data):
    print(decode)
    image=tf.image.decode_jpeg(image_data,channels=3)
    image=tf.image.resize(image,IMAGE_SIZE)
    image=tf.cast(image,tf.float32)/255.0
    return image

def read_image(image):
    print('read')
    image=tf.io.read_file(image)
    image=decode_image(image)
    return image

def get_dataset(image):
    dataset=tf.data.Dataset.from_tensor_slices(image)
    dataset=dataset.map(read_image,num_parallel_calls='AUTO')
    dataset=dataset.batch(BATCH_SIZE)
    dataset=dataset.prefetch(1)
    return dataset

# %%
imgpath=pd.Series(path+'/'+train_data['image']) 
images = get_dataset(pd.Series(imgpath))
# Out:
# read
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15528/2990957534.py in <module>
#       1 imgpath=pd.Series(path+'/'+train_data['image'])
# ----> 2 images = get_dataset(pd.Series(imgpath))
#
# ~\AppData\Local\Temp/ipykernel_15528/2281769827.py in get_dataset(image)
#      14 def get_dataset(image):
#      15     dataset=tf.data.Dataset.from_tensor_slices(image)
# ---> 16     dataset=dataset.map(read_image,num_parallel_calls='AUTO')
#      17     dataset=dataset.batch(BATCH_SIZE)
#      18     dataset=dataset.prefetch(1)
#
# ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\data\ops\dataset_ops.py in map(self, map_func, num_parallel_calls, deterministic, name)
#    2016       return MapDataset(self, map_func, preserve_cardinality=True, name=name)
#    2017     else:
# -> 2018       return ParallelMapDataset(
# ...

# %%
images
# Out:
# <PrefetchDataset element_spec=TensorSpec(shape=(None, 512, 512, 3), dtype=tf.float32, name=None)>

# %%
model = ResNet50(include_top=False,weights='imagenet')

# %%
path = 
device = tf.device('/GPU:0')
img_size = 224

def preprocess_image(image_url):
    
    img = image.load_img(image_url, target_size=(img_size, img_size))
    x = image.img_to_array(img)
    x = np.expand_dims(x, axis=0)
    print(x.shape)
    
    with device:
        x = preprocess_input(x)
        pred = model.predict(x)
    
    return pred

# %%
image_embeddings=np.zeros((train_data.shape[0],1536))

for i,url in enumerate(train_data['image']):
    url=path+'/'+url
    #image_embeddings[i]
    x=preprocess_image(url)
    break
# Out:
# (1, 224, 224, 3)

# %%
import matplotlib.pyplot as plt

plt.imshow(train_image[2])
plt.show()

# %%
model.summary()
# Out:
# Model: "resnet50"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_1 (InputLayer)           [(None, None, None,  0           []
#                                  3)]
#
#  conv1_pad (ZeroPadding2D)      (None, None, None,   0           ['input_1[0][0]']
#                                 3)
#
#  conv1_conv (Conv2D)            (None, None, None,   9472        ['conv1_pad[0][0]']
#                                 64)
#
#  conv1_bn (BatchNormalization)  (None, None, None,   256         ['conv1_conv[0][0]']
#                                 64)
#
#  conv1_relu (Activation)        (None, None, None,   0           ['conv1_bn[0][0]']
#                                 64)
#
#  pool1_pad (ZeroPadding2D)      (None, None, None,   0           ['conv1_relu[0][0]']
#                                 64)
#
# ...

# %%
help(tf.keras.applications.resnet)
# Out:
# Help on package tensorflow.keras.applications.resnet in tensorflow.keras.applications:
#
# NAME
#     tensorflow.keras.applications.resnet - Public API for tf.keras.applications.resnet namespace.
#
# PACKAGE CONTENTS
#
#
# FILE
#     c:\users\manju\anaconda3\lib\site-packages\keras\api\_v2\keras\applications\resnet\__init__.py
